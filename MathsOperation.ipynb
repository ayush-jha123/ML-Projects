# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()

# %%
#Plotting a vector
plt.quiver(0,0,4,5)
plt.show()

# %%
plt.quiver(0,0,4,5,scale_units='xy',angles='xy',scale=1,color='b')
plt.quiver(0,0,-3,-6,scale_units='xy',angles='xy',scale=1,color='y')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %%
vector_1=np.asarray([0,0,2,3])
vector_2=np.asarray([0,0,3,-2])
sum=vector_1+vector_2
print(sum)
# Out:
# [0 0 5 1]

# %%
plt.quiver(0,0,2,3,scale_units='xy',angles='xy',scale=1,color='b')
plt.quiver(0,0,3,-2,scale_units='xy',angles='xy',scale=1,color='y')
plt.quiver(0,0,5,1,scale_units='xy',angles='xy',scale=1,color='r')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %%
vector_1=np.asarray([0,0,2,3])
vector_2=np.asarray([0,0,3,-2])
sub=vector_1-vector_2
print(sub)
# Out:
# [ 0  0 -1  5]

# %%
plt.quiver(0,0,2,3,scale_units='xy',angles='xy',scale=1,color='b')
plt.quiver(0,0,3,-2,scale_units='xy',angles='xy',scale=1,color='y')
plt.quiver(0,0,-1,5,scale_units='xy',angles='xy',scale=1,color='r')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %%
vector_1=np.asarray([0,0,2,3])
vector_2=2*vector_1

print(vector_2)
# Out:
# [0 0 4 6]

# %%
a=np.array([2,5])
b=np.array([8,-6])

a_dot_b=np.dot(a,b)
print(a_dot_b)
# Out:
# -14

# %%
a=np.array([2,5,6])
b=np.array([8,-6,7])

a_cross_b=np.cross(a,b)
print(a_cross_b)
# Out:
# [ 71  34 -52]

# %%
a = np.array([2, 5])

v = np.array([8, -6])

# magnitude of "v" vector
magnitude_of_v = np.sqrt(np.sum(v**2))

proj_of_a_on_v = (np.dot(a,v)/magnitude_of_v**2)*v

print('Projection of a vector on v vector = ', proj_of_a_on_v)
# Out:
# Projection of a vector on v vector =  [-1.12  0.84]

# %% [markdown]
# #Matrix Operatio

# %%
matrix_1=np.array([[2,3],[6,7]])
print(matrix_1)
# Out:
# [[2 3]
#  [6 7]]

# %%
matrix_1.shape
# Out:
# (2, 2)

# %%
random_matrix=np.random.rand(3,3)
print(random_matrix)
# Out:
# [[0.37599804 0.67026178 0.20690167]
#  [0.99602421 0.45967037 0.03237331]
#  [0.24038711 0.87766778 0.96656336]]

# %%
random_matrix_int=np.random.randint(100,size=(3,3))
print(random_matrix_int)
# Out:
# [[94 60 65]
#  [96 66 84]
#  [12 37 47]]

# %%
matrix_2=np.ones((2,3))
print(matrix_2)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]]

# %%
matrix_2=np.ones((2,3),dtype=int)
print(matrix_2)
# Out:
# [[1 1 1]
#  [1 1 1]]

# %%
matrix_2=np.zeros((2,3))
print(matrix_2)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
A=np.array([[2,3],[3,4]])
B=np.array([[4,5],[2,4]])
print(A)
print(B)
# Out:
# [[2 3]
#  [3 4]]
# [[4 5]
#  [2 4]]

# %%
sum=A+B
print(sum)
# Out:
# [[6 8]
#  [5 8]]

# %%
sub=A-B
print(sub)
# Out:
# [[-2 -2]
#  [ 1  0]]

# %%
product=np.multiply(A,B)
print(product)
# Out:
# [[ 8 15]
#  [ 6 16]]

# %%
A=5
B=np.array([[2,3,5],[3,4,6],[4,2,7]])

product=np.multiply(A,B)
print(product)
# Out:
# [[10 15 25]
#  [15 20 30]
#  [20 10 35]]

# %%
A=np.random.randint(5,size=(3,3))
B=np.random.randint(5,size=(3,4))

product=np.dot(A,B)
print(product)
# Out:
# [[ 9  6  6  6]
#  [22 18 13 23]
#  [21 16 13 19]]

# %%
#Element wise matrix mul
A=np.random.randint(5,size=(3,3))
B=np.random.randint(5,size=(3,3))

product=np.multiply(A,B) # for np.multiply both matrices should have same shape
print(product)
# Out:
# [[0 4 1]
#  [0 8 8]
#  [0 4 8]]
